# %%
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import numpy as np
import time
import os
import seaborn as sns
import simfin as sf
from sklearn.model_selection import train_test_split, GridSearchCV, GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
import joblib

# SimFin setup — register free at https://simfin.com
# Paste your key here — do NOT commit this to GitHub
SIMFIN_API_KEY = 'YOUR_SIMFIN_API_KEY_HERE'
sf.set_api_key(SIMFIN_API_KEY)
sf.set_data_dir(os.path.expanduser('~/simfin_data/'))
print('SimFin configured.')

# %%
# ============================================================
# fetchStockInfo — SimFin backed (historical fundamentals per year)
#
# THE FIX: Instead of applying today's EPS/ROE/PE across all 5 years,
# we pull the ACTUAL fundamentals for each year from SimFin.
# This means 2021 rows use 2021 EPS, 2022 rows use 2022 EPS, etc.
# ============================================================

SECTOR_MAP = {
    'Technology':             'Technology',
    'Financial Services':     'Financials',
    'Healthcare':             'Healthcare',
    'Consumer Cyclical':      'Discretionary',
    'Consumer Defensive':     'Staples',
    'Energy':                 'Energy',
    'Industrials':            'Industrials',
    'Utilities':              'Utilities',
    'Real Estate':            'Utilities',
    'Communication Services': 'Technology',
    'Basic Materials':        'Industrials',
}

# Load SimFin datasets once — downloads and caches locally on first run
print('Loading SimFin datasets (first run downloads, then cached)...')
sf_income  = sf.load_income(variant='annual',  market='us')
sf_balance = sf.load_balance(variant='annual', market='us')
sf_derived = sf.load_derived(variant='annual', market='us')
print(f'  Income rows:  {len(sf_income)}')
print(f'  Balance rows: {len(sf_balance)}')
print(f'  Derived rows: {len(sf_derived)}')


def get_historical_fundamentals(ticker, year):
    """
    Return actual fundamentals for a ticker in a specific year from SimFin.
    Picks the most recent annual report on or before the target year.
    Returns a dict or None if data unavailable.
    """
    try:
        all_tickers = sf_income.index.get_level_values('Ticker').unique()
        if ticker not in all_tickers:
            return None

        inc = sf_income.xs(ticker, level='Ticker').copy()
        bal = sf_balance.xs(ticker, level='Ticker').copy()
        der = sf_derived.xs(ticker, level='Ticker').copy() if ticker in sf_derived.index.get_level_values('Ticker').unique() else None

        inc.index = pd.to_datetime(inc.index)
        bal.index = pd.to_datetime(bal.index)

        inc_yr = inc[inc.index.year <= year]
        bal_yr = bal[bal.index.year <= year]

        if inc_yr.empty or bal_yr.empty:
            return None

        ir = inc_yr.iloc[-1]
        br = bal_yr.iloc[-1]

        shares = ir.get('Shares (Diluted)') or br.get('Shares (Diluted)')
        if not shares or shares == 0:
            return None

        net_income   = ir.get('Net Income')
        tot_equity   = br.get('Total Equity')
        tot_assets   = br.get('Total Assets')
        lt_debt      = br.get('Long Term Debt') or 0
        revenue      = ir.get('Revenue')
        op_income    = ir.get('Operating Income')

        eps = (net_income / shares) if net_income else None
        bv  = (tot_equity / shares) if tot_equity else None
        roe = (net_income / tot_equity) if net_income and tot_equity and tot_equity != 0 else None
        roa = (net_income / tot_assets) if net_income and tot_assets else None
        opm = (op_income / revenue) if op_income and revenue and revenue != 0 else None
        de  = (lt_debt / tot_equity) if tot_equity and tot_equity != 0 else None

        # Override with SimFin derived ratios where available
        if der is not None:
            der.index = pd.to_datetime(der.index)
            der_yr = der[der.index.year <= year]
            if not der_yr.empty:
                dr = der_yr.iloc[-1]
                roe = dr.get('Return on Equity', roe)
                roa = dr.get('Return on Assets', roa)

        return {'eps': eps, 'book_value': bv, 'roe': roe,
                'roa': roa, 'op_margin': opm, 'de': de, 'revenue': revenue}
    except Exception:
        return None


def fetchStockInfo(ticker_symbol):
    """
    Builds a 5-year feature DataFrame where each year uses the
    ACTUAL historical fundamentals from that year (via SimFin).
    Falls back to current yfinance values only if SimFin has no data.
    """
    ticker_symbol = ticker_symbol.upper().strip()

    # Price history
    ticker_obj    = yf.Ticker(ticker_symbol)
    stock_history = ticker_obj.history(period='5y')
    if stock_history.empty:
        print(f'  Skipping {ticker_symbol}: no price history.')
        return None, 0

    time.sleep(0.3)
    info = ticker_obj.info

    # Sector from yfinance (does not change)
    raw_sector = info.get('sector')
    if not raw_sector:
        print(f'  Skipping {ticker_symbol}: no sector.')
        return None, 0
    sector = SECTOR_MAP.get(raw_sector)
    if not sector:
        print(f'  Skipping {ticker_symbol}: unmapped sector {raw_sector}.')
        return None, 0

    # SP500
    sp500 = yf.Ticker('^GSPC').history(period='5y')['Close']
    stock_history.index = stock_history.index.tz_convert(None)
    sp500.index         = sp500.index.tz_convert(None)
    sp500 = sp500.reindex(stock_history.index).ffill()

    # Build features year by year using historical fundamentals
    current_year  = pd.Timestamp.today().year
    yearly_frames = []

    for year in range(current_year - 4, current_year + 1):
        year_hist = stock_history[stock_history.index.year == year].copy()
        if year_hist.empty:
            continue

        # Get ACTUAL fundamentals for this year
        fund = get_historical_fundamentals(ticker_symbol, year)

        if fund is None:
            # Fallback to current yfinance values
            print(f'  {ticker_symbol} {year}: SimFin missing, using current yfinance values')
            eps = info.get('trailingEps') or info.get('forwardEps')
            bv  = info.get('bookValue')
            roe = info.get('returnOnEquity')
            roa = info.get('returnOnAssets')
            opm = info.get('operatingMargins')
            de_raw = info.get('debtToEquity')
            de  = (de_raw / 100) if de_raw else 0.0
        else:
            eps = fund['eps']
            bv  = fund['book_value']
            roe = fund['roe']
            roa = fund['roa']
            opm = fund['op_margin']
            de  = fund['de'] if fund['de'] else 0.0

        if any(v is None for v in [eps, bv, roe, roa, opm]):
            continue

        # Graham value using THIS YEAR's EPS and book value
        gv = float(np.sqrt(22.5 * abs(eps * bv))) if eps and bv and (eps * bv) != 0 else 0

        # PE — use year average price / year EPS as a proxy
        pe = year_hist['Close'].mean() / eps if eps and eps != 0 else None
        if pe is None:
            continue

        # P/B and P/S — compute from price and fundamentals
        p2b = year_hist['Close'].mean() / bv if bv and bv != 0 else None
        p2s = (info.get('marketCap') / fund['revenue']) if fund and fund.get('revenue') and fund['revenue'] != 0 else None
        dy  = info.get('dividendYield') or 0.0
        rg  = info.get('revenueGrowth')  # still current — SimFin YoY can be added later

        if any(v is None for v in [p2b, rg]):
            continue

        def determine_label(row):
            price = row['Close']
            if gv == 0: return 1
            base = 0 if price < gv * 0.85 else (2 if price > gv * 1.15 else 1)
            if base == 2 and (roe > 0.25 and opm > 0.25 and pe < 50): return 1
            if base == 0 and (de > 5.0 and rg < -0.15): return 1
            return base

        df_y = year_hist.copy()
        df_y['Target']          = df_y.apply(determine_label, axis=1)
        df_y['PE_Ratio']        = pe
        df_y['ROE']             = roe
        df_y['ROA']             = roa
        df_y['EPS']             = eps
        df_y['Dividend_Yield']  = dy
        df_y['Debt_to_Equity']  = de
        df_y['Price_to_Book']   = p2b
        df_y['Price_to_Sales']  = p2s if p2s else 0.0
        df_y['Revenue_Growth']  = rg
        df_y['Operating_Margin']= opm
        df_y['Momentum']        = stock_history['Close'].rolling(30).mean() / stock_history['Close'].rolling(90).mean()
        df_y['Volatility']      = stock_history['Close'].pct_change().rolling(30).std()
        df_y['sp500_close']     = sp500.reindex(df_y.index).ffill()
        yearly_frames.append(df_y)

    if not yearly_frames:
        print(f'  Skipping {ticker_symbol}: no yearly data assembled.')
        return None, 0

    # Required columns
    cols = [
        'PE_Ratio','ROE','ROA','EPS','Dividend_Yield','Debt_to_Equity',
        'Price_to_Book','Price_to_Sales','Revenue_Growth','Operating_Margin',
        'Momentum','Volatility','sp500_close','Target'
    ]
    df_final = pd.concat(yearly_frames)
    for c in cols:
        if c not in df_final.columns: df_final[c] = 0
    df_final = df_final[cols].ffill().fillna(0).iloc[90:]

    # Final Graham value from most recent year
    latest = get_historical_fundamentals(ticker_symbol, pd.Timestamp.today().year)
    if latest and latest['eps'] and latest['book_value']:
        gv_final = float(np.sqrt(22.5 * abs(latest['eps'] * latest['book_value'])))
    else:
        e = info.get('trailingEps') or 0
        b = info.get('bookValue') or 0
        gv_final = float(np.sqrt(22.5 * abs(e * b))) if e and b else 0

    return df_final, gv_final


print('fetchStockInfo (SimFin-backed) ready.')

# %%
data, intrinsic_price = fetchStockInfo("pltr")

# %%
# 1. DEFINE THE UNIVERSE (10 per sector)
sector_map = {
    'Technology': [
        # Original
        'AAPL', 'MSFT', 'NVDA', 'ORCL', 'ADBE', 'CRM', 'INTC', 'CSCO', 'AMD', 'IBM',
        # Added
        'QCOM', 'TXN', 'NOW', 'AMAT', 'MU', 'LRCX', 'KLAC', 'SNPS', 'CDNS', 'HPQ'
    ],
    'Financials': [
        # Original
        'JPM', 'BAC', 'GS', 'MS', 'WFC', 'C', 'BLK', 'PYPL', 'V', 'MA',
        # Added
        'AXP', 'USB', 'PNC', 'TFC', 'COF', 'SCHW', 'ICE', 'CME', 'CB', 'MMC'
    ],
    'Healthcare': [
        # Original
        'PFE', 'JNJ', 'UNH', 'ABBV', 'MRK', 'LLY', 'AMGN', 'TMO', 'GILD', 'BMY',
        # Added
        'CVS', 'MDT', 'ABT', 'DHR', 'BSX', 'ISRG', 'EW', 'ZTS', 'REGN', 'VRTX'
    ],
    'Discretionary': [
        # Original
        'TSLA', 'AMZN', 'F', 'GM', 'HD', 'NKE', 'SBUX', 'MCD', 'BKNG', 'NCLH',
        # Added
        'LOW', 'TJX', 'EBAY', 'MAR', 'HLT', 'YUM', 'DRI', 'ROST', 'ORLY', 'AZO'
    ],
    'Energy': [
        # Original
        'XOM', 'CVX', 'SHEL', 'BP', 'TTE', 'COP', 'SLB', 'EOG', 'MPC', 'VLO',
        # Added
        'PSX', 'PXD', 'HAL', 'BKR', 'OXY', 'DVN', 'HES', 'FANG', 'MRO', 'APA'
    ],
    'Staples': [
        # Original
        'WMT', 'KO', 'PEP', 'COST', 'PG', 'EL', 'CL', 'MO', 'TGT', 'PM',
        # Added
        'MDLZ', 'GIS', 'KHC', 'HSY', 'SYY', 'ADM', 'BG', 'CAG', 'MKC', 'CHD'
    ],
    'Industrials': [
        # Original
        'BA', 'CAT', 'GE', 'UPS', 'FDX', 'HON', 'LMT', 'MMM', 'DE', 'RTX',
        # Added
        'NOC', 'GD', 'EMR', 'ETN', 'PH', 'ROK', 'IR', 'CARR', 'OTIS', 'WAB'
    ],
    'Utilities': [
        # Original
        'NEE', 'DUK', 'SO', 'D', 'AEP', 'PLD', 'AMT', 'EQIX', 'CCI', 'O',
        # Added
        'EXC', 'XEL', 'WEC', 'ES', 'AWK', 'DTE', 'PPL', 'FE', 'ETR', 'AEE'
    ]
}
# --- RE-CHECKED BALANCING LOGIC ---
all_balanced_data = []
SAMPLES_PER_CLASS = 20 

for sector, tickers in sector_map.items():
    print(f"\n--- Balancing Sector: {sector} ---")
    for ticker in tickers:
        try:
            # 1. Fetch
            df_full, g_val = fetchStockInfo(ticker)
            
            # --- CRITICAL CHECK: Is there data? ---
            if df_full is None or df_full.empty:
                print(f"Skipping {ticker}: No data returned from fetcher.")
                continue

            # 2. Split classes
            c0 = df_full[df_full['Target'] == 0]
            c1 = df_full[df_full['Target'] == 1]
            c2 = df_full[df_full['Target'] == 2]

            # 3. Sample (only if class has data)
            s0 = c0.sample(n=min(len(c0), SAMPLES_PER_CLASS)) if not c0.empty else pd.DataFrame()
            s1 = c1.sample(n=min(len(c1), SAMPLES_PER_CLASS)) if not c1.empty else pd.DataFrame()
            s2 = c2.sample(n=min(len(c2), SAMPLES_PER_CLASS)) if not c2.empty else pd.DataFrame()

            # 4. Combine
            chunk = pd.concat([s0, s1, s2])
            if not chunk.empty:
                chunk['Sector'] = sector
                chunk['Ticker'] = ticker
                all_balanced_data.append(chunk)
                print(f"Collected {len(chunk)} samples for {ticker}")
            else:
                print(f"No samples found for {ticker} in any class.")

        except Exception as e:
            print(f"Skipping {ticker} due to error: {e}")

# --- STAGE 2: REDUCE TARGET 1 TO 400 ---
# --- STAGE 1: Combine everything collected in the loop ---
df_collected = pd.concat(all_balanced_data)

# --- STAGE 2: THE "ANTI-BIAS" FIX (The steps you provided) ---
# Find the smallest class size to determine our "cap"
min_size = min(len(df_collected[df_collected['Target']==0]), 
               len(df_collected[df_collected['Target']==1]), 
               len(df_collected[df_collected['Target']==2]))

print(f"Balancing dataset... Smallest class size is {min_size}")

# Sample that exact amount from each to create a perfect 1:1:1 ratio
final_df = pd.concat([
    df_collected[df_collected['Target']==0].sample(min_size, random_state=42),
    df_collected[df_collected['Target']==1].sample(min_size, random_state=42),
    df_collected[df_collected['Target']==2].sample(min_size, random_state=42)
]).sample(frac=1).reset_index(drop=True) # frac=1 shuffles the rows

# --- STAGE 3: Save and Verify ---
final_df.to_csv('balanced_stock_data.csv', index=False)

print("\n--- FINAL BALANCED COUNTS ---")
print(final_df['Target'].value_counts())
# Out:
# --- Balancing Sector: Technology ---
# Collected 20 samples for AAPL
# Collected 20 samples for MSFT
# Collected 40 samples for NVDA
# Collected 20 samples for ORCL
# Collected 20 samples for ADBE
# Collected 20 samples for CRM
#   INTC: computed P/E manually (-779.6666)
# Collected 20 samples for INTC
# Collected 20 samples for CSCO
# Collected 20 samples for AMD
# Collected 40 samples for IBM
# Collected 20 samples for QCOM
# Collected 20 samples for TXN
# Collected 20 samples for NOW
# Collected 20 samples for AMAT
# Collected 60 samples for MU
# Collected 20 samples for LRCX
# Collected 20 samples for KLAC
# Collected 20 samples for SNPS
# Collected 20 samples for CDNS
#   HPQ: computed D/E manually (-14.3233)
#   HPQ: computed ROE manually (-3.2855)
# Collected 20 samples for HPQ
#
# --- Balancing Sector: Financials ---
# Collected 60 samples for JPM
# Collected 40 samples for BAC
# Collected 60 samples for GS
# Collected 60 samples for MS
# Collected 40 samples for WFC
# Collected 40 samples for C
# Collected 40 samples for BLK
# Collected 54 samples for PYPL
# Collected 20 samples for V
# Collected 20 samples for MA
# Collected 40 samples for AXP
# Collected 40 samples for USB
# Collected 40 samples for PNC
# Collected 25 samples for TFC
# Collected 60 samples for COF
# Collected 40 samples for SCHW
# Collected 40 samples for ICE
# Collected 40 samples for CME
# Collected 40 samples for CB
# Collected 20 samples for MMC
#
# --- Balancing Sector: Healthcare ---
# Collected 40 samples for PFE
# Collected 20 samples for JNJ
# Collected 20 samples for UNH
#   ABBV: computed D/E manually (-20.9103)
# Collected 20 samples for ABBV
# Collected 20 samples for MRK
# Collected 20 samples for LLY
# Collected 20 samples for AMGN
# Collected 20 samples for TMO
# Collected 20 samples for GILD
# Collected 20 samples for BMY
# Collected 40 samples for CVS
# Collected 20 samples for MDT
# Collected 20 samples for ABT
# Collected 20 samples for DHR
# Collected 20 samples for BSX
# Collected 20 samples for ISRG
# Collected 20 samples for EW
# Collected 20 samples for ZTS
# Collected 40 samples for REGN
# Collected 40 samples for VRTX
#
# --- Balancing Sector: Discretionary ---
# Collected 20 samples for TSLA
# Collected 40 samples for AMZN
#   F: computed P/E manually (-5.9417)
# Collected 30 samples for F
# Collected 60 samples for GM
# Collected 20 samples for HD
# Collected 20 samples for NKE
#   SBUX: computed D/E manually (-3.0380)
#   SBUX: computed ROE manually (-0.1632)
# Collected 20 samples for SBUX
#   MCD: computed D/E manually (-30.5644)
#   MCD: computed ROE manually (-4.7734)
# Collected 20 samples for MCD
#   BKNG: computed D/E manually (-3.5047)
#   BKNG: computed ROE manually (-0.9756)
# Collected 20 samples for BKNG
# Collected 36 samples for NCLH
#   LOW: computed D/E manually (-4.5056)
#   LOW: computed ROE manually (-0.6692)
# Collected 20 samples for LOW
# Collected 20 samples for TJX
# Collected 39 samples for EBAY
#   MAR: computed D/E manually (-4.5715)
#   MAR: computed ROE manually (-0.6920)
# Collected 20 samples for MAR
#   HLT: computed D/E manually (-2.4647)
#   HLT: computed ROE manually (-0.2718)
# Collected 20 samples for HLT
#   YUM: computed D/E manually (-1.8043)
#   YUM: computed ROE manually (-0.2133)
# Collected 20 samples for YUM
# Collected 20 samples for DRI
# Collected 20 samples for ROST
#   ORLY: computed D/E manually (-11.1656)
#   ORLY: computed ROE manually (-3.3375)
# Collected 20 samples for ORLY
#   AZO: computed D/E manually (-4.3023)
#   AZO: computed ROE manually (-0.8406)
# Collected 20 samples for AZO
#
# --- Balancing Sector: Energy ---
# Collected 60 samples for XOM
# Collected 60 samples for CVX
# Collected 60 samples for SHEL
# Collected 20 samples for BP
# Collected 40 samples for TTE
# Collected 60 samples for COP
# Collected 60 samples for SLB
# Collected 60 samples for EOG
# Collected 60 samples for MPC
# Collected 60 samples for VLO
# Collected 60 samples for PSX
# $PXD: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
#   Skipping PXD: no price history returned.
# Skipping PXD: No data returned from fetcher.
# Collected 43 samples for HAL
# Collected 60 samples for BKR
# Collected 60 samples for OXY
# Collected 60 samples for DVN
# $HES: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
#   Skipping HES: no price history returned.
# Skipping HES: No data returned from fetcher.
# Collected 60 samples for FANG
# $MRO: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
#   Skipping MRO: no price history returned.
# Skipping MRO: No data returned from fetcher.
# Collected 40 samples for APA
#
# --- Balancing Sector: Staples ---
# Collected 20 samples for WMT
# Collected 20 samples for KO
# Collected 20 samples for PEP
# Collected 20 samples for COST
# Collected 20 samples for PG
#   EL: computed P/E manually (-184.8431)
# Collected 20 samples for EL
# Collected 20 samples for CL
#   MO: computed D/E manually (-7.3504)
#   MO: computed ROE manually (-1.9805)
# Collected 20 samples for MO
# Collected 40 samples for TGT
#   PM: computed D/E manually (-4.9625)
#   PM: computed ROE manually (-1.1323)
# Collected 20 samples for PM
# Collected 20 samples for MDLZ
# Collected 40 samples for GIS
#   KHC: computed P/E manually (-4.7992)
# Collected 20 samples for KHC
# Collected 20 samples for HSY
# Collected 20 samples for SYY
# Collected 41 samples for ADM
# Collected 60 samples for BG
#   CAG: computed P/E manually (-86.0952)
# Collected 20 samples for CAG
# Collected 20 samples for MKC
# Collected 20 samples for CHD
#
# --- Balancing Sector: Industrials ---
# Collected 20 samples for BA
# Collected 27 samples for CAT
# Collected 60 samples for GE
# Collected 20 samples for UPS
#   Skipping FDX: debt-to-equity cannot be computed.
# Skipping FDX: No data returned from fetcher.
# Collected 20 samples for HON
# Collected 20 samples for LMT
# Collected 20 samples for MMM
# Collected 20 samples for DE
# Collected 40 samples for RTX
# Collected 20 samples for NOC
# Collected 40 samples for GD
# Collected 20 samples for EMR
# Collected 40 samples for ETN
# Collected 40 samples for PH
# Collected 20 samples for ROK
# Collected 20 samples for IR
# Collected 20 samples for CARR
#   OTIS: computed D/E manually (-1.5828)
#   OTIS: computed ROE manually (-0.2574)
# Collected 20 samples for OTIS
# Collected 60 samples for WAB
#
# --- Balancing Sector: Utilities ---
# Collected 37 samples for NEE
# Collected 60 samples for DUK
# Collected 40 samples for SO
# Collected 60 samples for D
# Collected 60 samples for AEP
# Collected 20 samples for PLD
# Collected 20 samples for AMT
# Collected 20 samples for EQIX
#   CCI: computed D/E manually (-18.0370)
#   CCI: computed ROE manually (-0.6729)
# Collected 20 samples for CCI
# Collected 20 samples for O
# Collected 52 samples for EXC
# Collected 42 samples for XEL
# Collected 40 samples for WEC
# Collected 60 samples for ES
# Collected 20 samples for AWK
# Collected 40 samples for DTE
# Collected 60 samples for PPL
# Collected 40 samples for FE
# Collected 60 samples for ETR
# Collected 50 samples for AEE
# Balancing dataset... Smallest class size is 850
#
# --- FINAL BALANCED COUNTS ---
# Target
# 1    850
# 2    850
# 0    850
# Name: count, dtype: int64

# %%
df = pd.read_csv('balanced_stock_data.csv')
print(df['Target'].value_counts())

# Visualize for your report
df['Target'].value_counts().plot(kind='bar', title='Distribution of Valuation Classes')
plt.xlabel('Class (0: Under, 1: Fair, 2: Over)')
plt.ylabel('Number of Samples')
plt.show()
#reduce bias is overvalued set take out remove sample classes for targets 
#use my dataset manual to check out from the data 
#1 reduce to 400-300
#varation of data  mean mode and std
# Out:
# Target
# 1    850
# 2    850
# 0    850
# Name: count, dtype: int64

# %%
# List the features you want to analyze (excluding the Target itself)
# These should match the names in your CSV
analysis_features = ['PE_Ratio', 'ROE', 'Momentum', 'Volatility', 'Debt_to_Equity', 'Revenue_Growth']

print("--- DESCRIPTIVE STATISTICS BY CLASS ---")
print("Class 0: Undervalued | Class 1: Fair | Class 2: Overvalued\n")

for feat in analysis_features:
    if feat in df.columns:
        print(f"Analysis for: {feat}")
        
        # Calculate stats grouped by the Target class
        stats = df.groupby('Target')[feat].agg(['mean', 'median', 'std']).round(3)
        
        # Renaming for clarity in your report
        stats.index = ['Undervalued (0)', 'Fair (1)', 'Overvalued (2)']
        print(stats)
        print("-" * 40)

# Save this summary to a CSV so you can put it in your dissertation table
summary_table = df.groupby('Target')[analysis_features].agg(['mean', 'std']).round(3)
summary_table.to_csv('feature_variation_summary.csv')
print("\nSummary table saved to 'feature_variation_summary.csv'")# List the features you want to analyze (excluding the Target itself)
# These should match the names in your CSV
analysis_features = ['PE_Ratio', 'ROE', 'Momentum', 'Volatility', 'Debt_to_Equity', 'Revenue_Growth']

print("--- DESCRIPTIVE STATISTICS BY CLASS ---")
print("Class 0: Undervalued | Class 1: Fair | Class 2: Overvalued\n")

for feat in analysis_features:
    if feat in df.columns:
        print(f"Analysis for: {feat}")
        
        # Calculate stats grouped by the Target class
        stats = df.groupby('Target')[feat].agg(['mean', 'median', 'std']).round(3)
        
        # Renaming for clarity in your report
        stats.index = ['Undervalued (0)', 'Fair (1)', 'Overvalued (2)']
        print(stats)
        print("-" * 40)

# Save this summary to a CSV so you can put it in your dissertation table
summary_table = df.groupby('Target')[analysis_features].agg(['mean', 'std']).round(3)

print("\nSummary table saved to 'feature_variation_summary.csv'")

# %%
# Filter only features that exist in the dataframe
features_to_plot = [f for f in analysis_features if f in df.columns]

if not features_to_plot:
    print("Error: None of the requested features found in the CSV.")
else:
    # UPDATED: Changed grid to 3 rows, 2 columns to fit all 6 features
    plt.figure(figsize=(16, 18)) 
    
    # Define colors for the classes
    palette = {0: 'green', 1: 'blue', 2: 'red'}
    labels = {0: 'Undervalued (Class 0)', 1: 'Fair (Class 1)', 2: 'Overvalued (Class 2)'}
    
    for i, feature in enumerate(features_to_plot):
        # UPDATED: (3 rows, 2 columns, index)
        plt.subplot(3, 2, i + 1) 
        
        # Create the bell curves (KDE plots)
        for target_val in sorted(df['Target'].unique()):
            subset = df[df['Target'] == target_val]
            sns.kdeplot(subset[feature], 
                        fill=True, 
                        label=labels.get(target_val, f'Class {target_val}'), 
                        color=palette.get(target_val, 'gray'),
                        alpha=0.4,
                        linewidth=2)
        
        plt.title(f'Bell Curve Distribution: {feature}', fontsize=14)
        plt.xlabel(f'{feature} Value', fontsize=12)
        plt.ylabel('Density', fontsize=12)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.legend()

    plt.tight_layout()
    plt.savefig('feature_bell_curves.png')
    print("Success: Bell curves saved as feature_bell_curves.png")# Filter only features that exist in the dataframe

# %%
corr_matrix = df.drop(['Ticker', 'Sector','Timestamp'], axis=1, errors='ignore').corr()

plt.figure(figsize=(12, 8)) 
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5) 
plt.title("Feature Correlation Matrix: Identifying Market Drivers") 
plt.savefig("correlation_heatmap.png") 
plt.show()

# %%
# 1. Drop non-numeric columns for the correlation
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# 2. Calculate the correlation specifically against the 'Target'
target_corr = numeric_df.corr()['Target'].sort_values(ascending=False)

# 3. Plotting the bar chart
plt.figure(figsize=(10, 6))
target_corr.drop('Target').plot(kind='bar', color='skyblue')
plt.title("Correlation of Independent Variables with Target (Valuation Class)")
plt.ylabel("Correlation Coefficient")
plt.axhline(0, color='black', lw=1)
plt.savefig("correlation_barchart.png")
plt.show()

# %%
data, intrinsic_price = fetchStockInfo("pltr")
table_data = data.tail(5).copy()
table_data = table_data.round(3)

# 2. Create the Plot
fig, ax = plt.subplots(figsize=(14, 4)) # Adjust size for your report
ax.axis('tight')
ax.axis('off')

# 3. Create the Table
table = ax.table(cellText=table_data.values, 
                 colLabels=table_data.columns, 
                 cellLoc='center', 
                 loc='center',
                 colColours=["#f2f2f2"] * len(table_data.columns)) # Light grey header

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.7) # Scale for better spacing

plt.title("Latest Stock Feature Matrix", fontsize=14, pad=20)
plt.show()

# %%
# ============================================================
# DATA PREP — Fixed for honest evaluation (3 bugs patched)
# ============================================================
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold

df = pd.read_csv('balanced_stock_data.csv')
df = pd.get_dummies(df, columns=['Sector'])
# NEW: split by TICKER -> a ticker is in train OR test, never both
all_tickers  = df['Ticker'].unique()
rng          = np.random.default_rng(42)
rng.shuffle(all_tickers)
split_point  = int(len(all_tickers) * 0.70)  # 70/30 split by ticker
train_tickers = all_tickers[:split_point]
test_tickers  = all_tickers[split_point:]

train_mask = df['Ticker'].isin(train_tickers)
test_mask  = df['Ticker'].isin(test_tickers)

X = df.drop(['Target', 'Ticker', 'Timestamp'], axis=1, errors='ignore')
y = df['Target']
groups = df['Ticker']  # kept for GroupKFold in GridSearch

X_train, X_test = X[train_mask], X[test_mask]
y_train, y_test = y[train_mask], y[test_mask]
groups_train    = groups[train_mask]

# Scale Data (Required for ANN and KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

print(f"Train tickers: {len(train_tickers)} | Test tickers: {len(test_tickers)}")
print(f"Train rows: {len(X_train)} | Test rows: {len(X_test)}")
print(f"Training on {len(X.columns)} features: {X.columns.tolist()}")
print(f"\nTest set class balance:\n{y_test.value_counts().sort_index()}")
# Out:
# Train tickers: 109 | Test tickers: 47
# Train rows: 1748 | Test rows: 802
# Training on 21 features: ['PE_Ratio', 'ROE', 'ROA', 'EPS', 'Dividend_Yield', 'Debt_to_Equity', 'Price_to_Book', 'Price_to_Sales', 'Revenue_Growth', 'Operating_Margin', 'Momentum', 'Volatility', 'sp500_close', 'Sector_Discretionary', 'Sector_Energy', 'Sector_Financials', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Staples', 'Sector_Technology', 'Sector_Utilities']
#
# Test set class balance:
# Target
# 0    253
# 1    288
# 2    261
# Name: count, dtype: int64

# %%
# --- FIX 3: cap max_depth (50 was memorising) + use GroupKFold so the same
# ticker never appears in both the CV train and validation fold ---
from sklearn.model_selection import GroupKFold

param_rf = {
    'n_estimators': [100, 300],
    'max_depth': [5, 10, 15]   # removed 50 — way too deep for 1311 rows
}
group_cv = GroupKFold(n_splits=5)
rf_model = RandomForestClassifier(random_state=42, class_weight='balanced')
grid_rf  = GridSearchCV(rf_model, param_rf, cv=group_cv, n_jobs=-1)
grid_rf.fit(X_train, y_train, groups=groups_train)
y_pred_rf = grid_rf.predict(X_test)

print(f"Best Params: {grid_rf.best_params_}")
print(classification_report(y_test, y_pred_rf))
# Out:
# Best Params: {'max_depth': 15, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.73      0.60      0.66       253
#            1       0.67      0.42      0.52       288
#            2       0.57      0.91      0.70       261
#
#     accuracy                           0.63       802
#    macro avg       0.66      0.64      0.62       802
# weighted avg       0.66      0.63      0.62       802

# %%
param_xgb = {
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200],
    'max_depth': [3, 4],
    'subsample': [0.8],
    'colsample_bytree': [0.6]
}

xgb_model = XGBClassifier(
    eval_metric='mlogloss',
    random_state=42,
    reg_lambda=1
)
# Use GroupKFold so the same ticker never leaks across CV folds
group_cv  = GroupKFold(n_splits=5)
grid_xgb  = GridSearchCV(xgb_model, param_xgb, cv=group_cv, n_jobs=-1)
grid_xgb.fit(X_train, y_train, groups=groups_train)
y_pred_xgb = grid_xgb.predict(X_test)

print(f"Best Params: {grid_xgb.best_params_}")
print(classification_report(y_test, y_pred_xgb))
# Out:
# Best Params: {'colsample_bytree': 0.6, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.8}
#               precision    recall  f1-score   support
#
#            0       0.65      0.73      0.69       253
#            1       0.57      0.42      0.49       288
#            2       0.67      0.78      0.72       261
#
#     accuracy                           0.64       802
#    macro avg       0.63      0.65      0.63       802
# weighted avg       0.63      0.64      0.63       802

# %%
param_ann = {
    'hidden_layer_sizes': [(64, 32), (100,)],
    'alpha': [0.0001, 0.05]
}
group_cv  = GroupKFold(n_splits=5)
grid_ann  = GridSearchCV(MLPClassifier(max_iter=1000, random_state=42), param_ann, cv=group_cv, n_jobs=-1)
grid_ann.fit(X_train_scaled, y_train, groups=groups_train)
y_pred_ann = grid_ann.predict(X_test_scaled)

print(f"Best Params: {grid_ann.best_params_}")
print(classification_report(y_test, y_pred_ann))
# Out:
# Best Params: {'alpha': 0.0001, 'hidden_layer_sizes': (100,)}
#               precision    recall  f1-score   support
#
#            0       0.73      0.43      0.54       253
#            1       0.58      0.57      0.57       288
#            2       0.57      0.81      0.67       261
#
#     accuracy                           0.60       802
#    macro avg       0.63      0.60      0.60       802
# weighted avg       0.63      0.60      0.60       802

# %%
param_knn = {
    'n_neighbors': [3, 7, 15],
    'weights': ['uniform', 'distance']
}
group_cv  = GroupKFold(n_splits=5)
grid_knn  = GridSearchCV(KNeighborsClassifier(), param_knn, cv=group_cv, n_jobs=-1)
grid_knn.fit(X_train_scaled, y_train, groups=groups_train)
y_pred_knn = grid_knn.predict(X_test_scaled)

print(f"Best Params: {grid_knn.best_params_}")
print(classification_report(y_test, y_pred_knn))
# Out:
# Best Params: {'n_neighbors': 3, 'weights': 'uniform'}
#               precision    recall  f1-score   support
#
#            0       0.59      0.62      0.60       253
#            1       0.51      0.43      0.47       288
#            2       0.56      0.64      0.60       261
#
#     accuracy                           0.56       802
#    macro avg       0.56      0.56      0.56       802
# weighted avg       0.55      0.56      0.55       802

# %%
# 1. Evaluate the Best Model found by GridSearch
best_rf = grid_rf.best_estimator_
importances = best_rf.feature_importances_
feature_names = X.columns

# Create a DataFrame to view them clearly
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

print("\n--- Feature Ranking for your Model ---")
print(importance_df)
y_pred_rf = best_rf.predict(X_test)

# 2. Simple Performance Printout
print("--- MODEL BACKTEST RESULTS ---")
print(f"Best Parameters: {grid_rf.best_params_}")
print(f"Overall Accuracy: {accuracy_score(y_test, y_pred_rf):.2%}")
print("\nDetailed Classification Report:")
print(classification_report(y_test, y_pred_rf))

# 3. Simple Visual: Confusion Matrix
# This shows exactly where the model "disagrees" with the Graham Formula
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Undervalued', 'Fair', 'Overvalued'],
            yticklabels=['Undervalued', 'Fair', 'Overvalued'])
plt.xlabel('Model Prediction')
plt.ylabel('Actual Graham Label')
plt.title('Backtest: Prediction vs. Reality')
plt.show()

# %%
test_tickers = [
    # --- THE TECH GIANTS (High PE, High Growth) ---
    "NVDA", # Nvidia: Extreme growth vs low book value.
    "MSFT", # Microsoft: Massive quality premiums.
    "AAPL",# Apple: High ROE, but expensive by Graham math.
    "TSLA",
    "SNOW",
    "CAT",
    "JNJ",
    
    
    # --- THE SPECULATIVE & VOLATILE ---
    "COIN", # Coinbase: High volatility, fluctuates wildy from Graham's anchor.
    "PLTR", # Palantir: Data/AI growth play with non-traditional financials.
    
    # --- THE VALUE TRAPS / DEBT HEAVY ---
    "T",    # AT&T: High debt, low growth. Will AI call it overvalued despite low price?
    "F",    # Ford: Classic industrial. Does AI agree with the low Graham valuation?
    "BA",   # Boeing: High debt and operational issues.
    
    # --- THE CONSISTENT QUALITY (AI should love these) ---
    "COST", # Costco: High PE usually, but incredible efficiency/ROE.
    "V",    # Visa: Asset-light, ultra-high margins.
    "PG",   # Procter & Gamble: Defensive, steady metrics.
    
    # --- THE RECOVERY / TRANSITION PLAYS ---
    "DIS",  # Disney: Moving from legacy to streaming growth.
    "INTC", # Intel: Struggling legacy tech. A test of "Momentum" vs "Value."
    
    # --- THE "STRICT VALUE" PLAYS ---
    "BRK-B",# Berkshire Hathaway: The king of value.
    "JPM" , "XOM", "CVX", "COP", "OXY", "DVN", "MRO", "HAL", "SLB", "PSX", "VLO",
    "MPC", "HES", "EOG", "PXD", "BP", "SHEL", "TTE", "E", "EC", "YPF",

    # --- FINANCIALS (low P/B, decent ROE, your Graham formula works here) ---
    "JPM", "BAC", "WFC", "C", "USB", "PNC", "TFC", "CFG", "KEY", "HBAN",
    "RF", "FITB", "MTB", "ZION", "FHN", "BEN", "IVZ", "GS", "MS", "MET",

    # --- INDUSTRIALS (steady earnings, real assets) ---
    "GE", "HON", "MMM", "CAT", "DE", "EMR", "ETN", "PH", "ITW", "DOV",
    "ROK", "IR", "CARR", "TXT", "LMT", "NOC", "RTX", "GD", "HII", "BWA",

    # --- HEALTHCARE / PHARMA (strong EPS, beaten down valuations) ---
    "JNJ", "PFE", "MRK", "ABBV", "BMY", "GILD", "CVS", "CI", "HUM", "CNC",
    "MOH", "AMGN", "BIIB", "VTRS", "OGN", "JAZZ", "PBH", "PRGO", "ENR", "BCO",

    # --- STAPLES (consistent EPS, dividends, model likes dividend yield) ---
    "KO", "PEP", "KHC", "MO", "BTI", "GIS", "K", "CPB", "CAG", "SJM",
    "HRL", "TSN", "PG", "CL", "CHD", "SPB", "CENT", "COTY", "KR", "SFM",

    # --- BEATEN DOWN / LOW P/E ---
    "INTC", "BA", "T", "VZ", "DIS", "WBD", "PARA", "F", "GM", "STLA",  # JPMorgan: Financial sector test for the Graham Formula.
]
print("\n--- FINAL AI VALIDATION (Clean & Bulletproof) ---")

for ticker in test_tickers:
    try:
        # 1. Fetch RAW data for Graham Math and Price
        t = yf.Ticker(ticker)
        info = t.info
        # Get just the very last price point
        hist = t.history(period="1d")
        if hist.empty: continue
        current_price = hist['Close'].iloc[-1]
        
        # 2. Get AI Features and Graham Value from your function
        # (df_live contains only the columns the AI needs)
        pe_ratio = info.get('trailingPE', 0)
        df_live, g_val = fetchStockInfo(ticker)
        if df_live.empty: continue
        
        # 3. Create Template Row (Must match X_train columns exactly)
        input_row = pd.DataFrame(0.0, index=[0], columns=X.columns)
        
        # 4. Fill Features (using the most recent row from fetchStockInfo)
        latest_data = df_live.iloc[-1]
        for col in X.columns:
            if col in latest_data:
                input_row.loc[0, col] = float(latest_data[col])
            # Handle Sector columns (One-Hot Encoding)
            elif col.startswith('Sector_'):
                sector_name = latest_data.get('Sector', 'Unknown')
                if col == f"Sector_{sector_name}":
                    input_row.loc[0, col] = 1.0

        # 5. Scale and Predict
       
        ai_idx = grid_xgb.predict(input_row)[0]
        
        # 6. Graham Label Logic
        if current_price < (g_val * 0.9): formula_idx = 0
        elif current_price > (g_val * 1.1): formula_idx = 2
        else: formula_idx = 1
        
        # Mapping
        labels = {0: "Undervalued", 1: "Fair", 2: "Overvalued"}
        
        print(f"STOCK: {ticker: <5} | Price: {current_price: >7.2f} |  P/E: {pe_ratio: >7.2f} | Graham: {g_val: >7.2f}")
        print(f"  > Graham Says: {labels[formula_idx]}")
        print(f"  > AI Says:     {labels[ai_idx]}")
        
        if formula_idx != ai_idx:
            print("  *** DISRUPTION DETECTED ***")
        print("-" * 45)
            
    except Exception as e:
        print(f"Error testing {ticker}: {e}")
# Out:
# --- FINAL AI VALIDATION (Clean & Bulletproof) ---
# STOCK: NVDA  | Price:  184.77 |  P/E:   37.71 | Graham:   26.71
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: MSFT  | Price:  405.76 |  P/E:   25.38 | Graham:  137.58
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: AAPL  | Price:  260.83 |  P/E:   33.02 | Graham:   32.65
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: TSLA  | Price:  399.23 |  P/E:  369.66 | Graham:   23.07
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
#   SNOW: computed P/E manually (-44.4975)
# STOCK: SNOW  | Price:  175.32 |  P/E:    0.00 | Graham:   22.32
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: CAT   | Price:  716.68 |  P/E:   38.16 | Graham:  139.14
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: JNJ   | Price:  243.71 |  P/E:   22.08 | Graham:   91.72
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: COIN  | Price:  196.52 |  P/E:   44.26 | Graham:   74.28
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: PLTR  | Price:  151.14 |  P/E:  239.90 | Graham:    6.62
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: T     | Price:   27.71 |  P/E:    9.12 | Graham:   32.78
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
#   F: computed P/E manually (-5.9417)
# STOCK: F     | Price:   12.24 |  P/E:    0.00 | Graham:   20.44
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: BA    | Price:  217.76 |  P/E:   87.81 | Graham:   19.68
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: COST  | Price:  997.36 |  P/E:   51.81 | Graham:  176.98
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: V     | Price:  314.43 |  P/E:   29.50 | Graham:   69.32
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: PG    | Price:  156.01 |  P/E:   23.08 | Graham:   58.49
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: DIS   | Price:  101.32 |  P/E:   14.92 | Graham:   96.60
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
#   INTC: computed P/E manually (-779.6666)
# STOCK: INTC  | Price:   46.78 |  P/E:    0.00 | Graham:    5.56
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: BRK-B | Price:  494.14 |  P/E:   15.92 | Graham: 18658.89
#   > Graham Says: Undervalued
#   > AI Says:     Overvalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: JPM   | Price:  288.73 |  P/E:   14.43 | Graham:  239.11
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: XOM   | Price:  148.13 |  P/E:   22.11 | Graham:   96.73
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: CVX   | Price:  186.29 |  P/E:   28.10 | Graham:  118.51
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: COP   | Price:  114.15 |  P/E:   17.98 | Graham:   86.72
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: OXY   | Price:   53.12 |  P/E:   39.35 | Graham:   29.24
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: DVN   | Price:   43.70 |  P/E:   10.48 | Graham:   48.40
#   > Graham Says: Fair
#   > AI Says:     Undervalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# $MRO: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# STOCK: HAL   | Price:   35.34 |  P/E:   23.56 | Graham:   20.56
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: SLB   | Price:   48.11 |  P/E:   20.47 | Graham:   30.38
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: PSX   | Price:  162.50 |  P/E:   15.06 | Graham:  132.69
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: VLO   | Price:  217.02 |  P/E:   28.67 | Graham:  116.27
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: MPC   | Price:  215.23 |  P/E:   16.28 | Graham:  132.13
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# HTTP Error 404:
# $HES: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# STOCK: EOG   | Price:  127.89 |  P/E:   14.02 | Graham:  106.70
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# $PXD: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# STOCK: BP    | Price:   39.94 |  P/E: 1997.00 | Graham:    1.25
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: SHEL  | Price:   85.11 |  P/E:   14.19 | Graham:   64.05
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: TTE   | Price:   80.08 |  P/E:   13.85 | Graham:   83.50
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
# STOCK: E     | Price:   48.36 |  P/E:   26.87 | Graham:   27.53
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
#   Skipping EC: Price to Sales cannot be computed.
# Error testing EC: 'NoneType' object has no attribute 'empty'
#   YPF: computed P/E manually (-17.3839)
# STOCK: YPF   | Price:   36.68 |  P/E:    0.00 | Graham:   36.56
#   > Graham Says: Fair
#   > AI Says:     Overvalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: JPM   | Price:  288.73 |  P/E:   14.43 | Graham:  239.11
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: BAC   | Price:   48.56 |  P/E:   12.75 | Graham:   57.41
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: WFC   | Price:   78.30 |  P/E:   12.51 | Graham:   86.56
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
# STOCK: C     | Price:  108.97 |  P/E:   15.61 | Graham:  131.44
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: USB   | Price:   51.95 |  P/E:   11.24 | Graham:   62.47
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: PNC   | Price:  206.39 |  P/E:   12.44 | Graham:  228.95
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
# STOCK: TFC   | Price:   46.65 |  P/E:   12.21 | Graham:   64.06
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: CFG   | Price:   58.89 |  P/E:   15.26 | Graham:   69.98
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: KEY   | Price:   19.76 |  P/E:   13.00 | Graham:   23.55
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: HBAN  | Price:   15.99 |  P/E:   11.50 | Graham:   20.76
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: RF    | Price:   26.76 |  P/E:   11.63 | Graham:   32.48
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: FITB  | Price:   46.59 |  P/E:   13.20 | Graham:   48.96
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
# STOCK: MTB   | Price:  204.12 |  P/E:   12.01 | Graham:  257.61
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: ZION  | Price:   55.42 |  P/E:    9.22 | Graham:   80.72
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: FHN   | Price:   23.00 |  P/E:   12.30 | Graham:   27.16
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: BEN   | Price:   25.22 |  P/E:   23.35 | Graham:   23.81
#   > Graham Says: Fair
#   > AI Says:     Overvalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
#   IVZ: computed P/E manually (-14.9812)
# STOCK: IVZ   | Price:   23.97 |  P/E:    0.00 | Graham:   28.07
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: GS    | Price:  833.81 |  P/E:   16.26 | Graham:  641.33
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: MS    | Price:  160.75 |  P/E:   15.74 | Graham:  121.60
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: MET   | Price:   70.60 |  P/E:   14.99 | Graham:   67.77
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
# STOCK: GE    | Price:  326.52 |  P/E:   40.46 | Graham:   56.87
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: HON   | Price:  240.61 |  P/E:   34.72 | Graham:   58.42
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: MMM   | Price:  155.25 |  P/E:   25.92 | Graham:   34.57
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: CAT   | Price:  716.68 |  P/E:   38.16 | Graham:  139.14
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: DE    | Price:  592.72 |  P/E:   33.45 | Graham:  197.03
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: EMR   | Price:  140.10 |  P/E:   34.34 | Graham:   57.55
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: ETN   | Price:  361.06 |  P/E:   34.62 | Graham:  108.41
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: PH    | Price:  950.39 |  P/E:   34.72 | Graham:  264.24
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: ITW   | Price:  273.29 |  P/E:   26.05 | Graham:   51.36
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: DOV   | Price:  210.26 |  P/E:   26.38 | Graham:   99.24
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: ROK   | Price:  374.07 |  P/E:   42.75 | Graham:   81.02
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: IR    | Price:   86.42 |  P/E:   59.60 | Graham:   29.01
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: CARR  | Price:   58.43 |  P/E:   34.57 | Graham:   25.06
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: TXT   | Price:   92.51 |  P/E:   18.07 | Graham:   72.14
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: LMT   | Price:  651.22 |  P/E:   30.30 | Graham:  119.13
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: NOC   | Price:  734.98 |  P/E:   25.25 | Graham:  277.33
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: RTX   | Price:  207.00 |  P/E:   41.65 | Graham:   73.73
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: GD    | Price:  355.59 |  P/E:   23.05 | Graham:  181.51
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: HII   | Price:  417.51 |  P/E:   27.09 | Graham:  211.71
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: BWA   | Price:   52.83 |  P/E:   41.27 | Graham:   27.51
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: JNJ   | Price:  243.71 |  P/E:   22.08 | Graham:   91.72
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: PFE   | Price:   27.16 |  P/E:   19.97 | Graham:   21.57
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: MRK   | Price:  117.09 |  P/E:   16.08 | Graham:   59.01
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
#   ABBV: computed D/E manually (-20.9103)
# STOCK: ABBV  | Price:  227.01 |  P/E:   96.19 | Graham:    9.91
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: BMY   | Price:   60.13 |  P/E:   17.38 | Graham:   26.58
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: GILD  | Price:  148.56 |  P/E:   21.94 | Graham:   52.79
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: CVS   | Price:   76.32 |  P/E:   54.91 | Graham:   43.02
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: CI    | Price:  262.44 |  P/E:   11.83 | Graham:  281.09
#   > Graham Says: Fair
#   > AI Says:     Undervalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: HUM   | Price:  173.62 |  P/E:   17.64 | Graham:  180.05
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
#   CNC: computed P/E manually (-2.6903)
# STOCK: CNC   | Price:   36.40 |  P/E:    0.00 | Graham:  111.14
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: MOH   | Price:  141.32 |  P/E:   15.84 | Graham:  126.54
#   > Graham Says: Overvalued
#   > AI Says:     Undervalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: AMGN  | Price:  375.43 |  P/E:   26.38 | Graham:   71.73
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: BIIB  | Price:  188.41 |  P/E:   21.41 | Graham:  156.92
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
#   VTRS: computed P/E manually (-4.6933)
# STOCK: VTRS  | Price:   14.08 |  P/E:    0.00 | Graham:   29.37
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: OGN   | Price:    6.48 |  P/E:    9.00 | Graham:    6.84
#   > Graham Says: Fair
#   > AI Says:     Overvalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
#   JAZZ: computed P/E manually (-31.8373)
# STOCK: JAZZ  | Price:  185.93 |  P/E:    0.00 | Graham:   96.11
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: PBH   | Price:   65.40 |  P/E:   17.26 | Graham:   57.42
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
#   PRGO: computed P/E manually (-0.9980)
# STOCK: PRGO  | Price:   10.10 |  P/E:    0.00 | Graham:   69.70
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: ENR   | Price:   17.84 |  P/E:    6.01 | Graham:   11.74
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: BCO   | Price:  110.95 |  P/E:   23.61 | Graham:   26.73
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: KO    | Price:   77.88 |  P/E:   25.62 | Graham:   22.62
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: PEP   | Price:  160.78 |  P/E:   26.80 | Graham:   44.89
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
#   KHC: computed P/E manually (-4.7992)
# STOCK: KHC   | Price:   23.66 |  P/E:    0.00 | Graham:   62.48
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
#   MO: computed D/E manually (-7.3504)
#   MO: computed ROE manually (-1.9805)
# STOCK: MO    | Price:   67.14 |  P/E:   16.30 | Graham:   13.93
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: BTI   | Price:   59.41 |  P/E:   12.69 | Graham:   54.46
#   > Graham Says: Fair
#   > AI Says:     Overvalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: GIS   | Price:   42.28 |  P/E:    9.09 | Graham:   42.74
#   > Graham Says: Fair
#   > AI Says:     Overvalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# HTTP Error 404:
# $K: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# STOCK: CPB   | Price:   24.68 |  P/E:   12.72 | Graham:   24.08
#   > Graham Says: Fair
#   > AI Says:     Undervalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
#   CAG: computed P/E manually (-86.0952)
# STOCK: CAG   | Price:   18.08 |  P/E:    0.00 | Graham:    8.94
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
#   SJM: computed P/E manually (-9.2002)
# STOCK: SJM   | Price:  108.47 |  P/E:    0.00 | Graham:  114.10
#   > Graham Says: Fair
#   > AI Says:     Overvalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: HRL   | Price:   23.34 |  P/E:   26.22 | Graham:   17.00
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: TSN   | Price:   60.24 |  P/E:  107.57 | Graham:   25.40
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: PG    | Price:  156.01 |  P/E:   23.08 | Graham:   58.49
#   > Graham Says: Overvalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: CL    | Price:   92.49 |  P/E:   35.17 | Graham:    1.99
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: CHD   | Price:  101.13 |  P/E:   33.49 | Graham:   33.91
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: SPB   | Price:   75.53 |  P/E:   17.86 | Graham:   88.08
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: CENT  | Price:   36.67 |  P/E:   14.97 | Graham:   37.35
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
#   COTY: computed P/E manually (-3.7581)
# STOCK: COTY  | Price:    2.33 |  P/E:    0.00 | Graham:    7.49
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: KR    | Price:   72.24 |  P/E:   46.91 | Graham:   20.68
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: SFM   | Price:   76.28 |  P/E:   14.37 | Graham:   41.80
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
#   INTC: computed P/E manually (-779.6666)
# STOCK: INTC  | Price:   46.78 |  P/E:    0.00 | Graham:    5.56
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: BA    | Price:  217.76 |  P/E:   87.81 | Graham:   19.68
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# STOCK: T     | Price:   27.71 |  P/E:    9.12 | Graham:   32.78
#   > Graham Says: Undervalued
#   > AI Says:     Fair
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: VZ    | Price:   50.71 |  P/E:   12.49 | Graham:   47.57
#   > Graham Says: Fair
#   > AI Says:     Overvalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
# STOCK: DIS   | Price:  101.32 |  P/E:   14.92 | Graham:   96.60
#   > Graham Says: Fair
#   > AI Says:     Fair
# ---------------------------------------------
# STOCK: WBD   | Price:   27.76 |  P/E:   95.72 | Graham:    9.72
#   > Graham Says: Overvalued
#   > AI Says:     Overvalued
# ---------------------------------------------
# HTTP Error 404:
# $PARA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
#   F: computed P/E manually (-5.9417)
# STOCK: F     | Price:   12.24 |  P/E:    0.00 | Graham:   20.44
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------
# STOCK: GM    | Price:   74.93 |  P/E:   22.91 | Graham:   70.53
#   > Graham Says: Fair
#   > AI Says:     Undervalued
#   *** DISRUPTION DETECTED ***
# ---------------------------------------------
#   STLA: computed P/E manually (-0.7727)
# STOCK: STLA  | Price:    6.90 |  P/E:    0.00 | Graham:   65.68
#   > Graham Says: Undervalued
#   > AI Says:     Undervalued
# ---------------------------------------------

# %%
import shap
import matplotlib.pyplot as plt

# 1. Get the best model
rf_best = grid_rf.best_estimator_ 

# 2. Re-initialize explainer
rf_explainer = shap.TreeExplainer(rf_best)
# 2. Initialize the Explainer
# We use 'X_test' as the data to explain
explainer = shap.TreeExplainer(rf_best)
shap_values = explainer.shap_values(X_test)

# 3. Create the Summary Plot
# This "Beeswarm" plot is the gold standard for AI research
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test)

# %%
# We wrap it in an Explanation object so SHAP can read it easily
# shap_values[..., 0] or shap_values[0] depending on your XGBoost version
# Let's try the most robust way:
class_0_values = shap_values[..., 0] if len(shap_values.shape) == 3 else shap_values[0]

shap.summary_plot(class_0_values, X_test, plot_type="bar")

# %%
# Explaining the very first stock in your test set
stock_to_explain = 0 
class_to_explain = 0 # 0=Under, 1=Fair, 2=Over

# 3. Create the Explanation object correctly
exp = shap.Explanation(
    values=shap_values[stock_to_explain, :, class_to_explain], 
    base_values=explainer.expected_value[class_to_explain], 
    data=X_test.iloc[stock_to_explain], 
    feature_names=X_test.columns
)

# 4. Plot
plt.figure(figsize=(10, 6))
shap.plots.waterfall(exp)
plt.show()

# %%
import joblib

# Save model as JSON
grid_xgb.best_estimator_.get_booster().save_model('valuation_model_xgb.json')

# Resave columns — must match new Market_Regime encoded columns
joblib.dump(list(X_train.columns), 'model_columns.pkl')

# Verify both
import os
print("JSON exists:", os.path.exists('valuation_model_xgb.json'))
print("PKL exists:", os.path.exists('model_columns.pkl'))
print("Columns saved:", list(X_train.columns))
# Out:
# JSON exists: True
# PKL exists: True
# Columns saved: ['PE_Ratio', 'ROE', 'ROA', 'EPS', 'Dividend_Yield', 'Debt_to_Equity', 'Price_to_Book', 'Price_to_Sales', 'Revenue_Growth', 'Operating_Margin', 'Momentum', 'Volatility', 'sp500_close', 'Sector_Discretionary', 'Sector_Energy', 'Sector_Financials', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Staples', 'Sector_Technology', 'Sector_Utilities']

# %% [markdown]
# ---
# # Chapter 6 — Testing and Evaluation
# ## Section 1: Model Evaluation — Confusion Matrices and Metric Tables
# Using the models and test split already in memory (`grid_xgb`, `grid_rf`, `grid_ann`, `grid_knn`, `X_test`, `y_test`).

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import (
    classification_report, accuracy_score,
    confusion_matrix, f1_score
)

CLASS_NAMES = ['Undervalued', 'Fair Value', 'Overvalued']

# ── All 4 models with their test predictions ──────────────────────────────
models = {
    'XGBoost':        y_pred_xgb,
    'Random Forest':  y_pred_rf,
    'MLP Neural Net': y_pred_ann,
    'KNN':            y_pred_knn,
}

fig, axes = plt.subplots(2, 2, figsize=(13, 10))
axes = axes.flatten()

for ax, (name, y_pred) in zip(axes, models.items()):
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
        ax=ax, linewidths=0.5
    )
    acc = accuracy_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred, average='macro')
    ax.set_title(f'{name}\nAccuracy: {acc:.1%}  |  Macro F1: {f1:.3f}',
                 fontsize=11, fontweight='bold')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('Actual Label')

plt.suptitle('Confusion Matrices — All Models', fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig('confusion_matrices_all.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved: confusion_matrices_all.png')

# %%
# ── Model comparison summary table ────────────────────────────────────────
rows = []
for name, y_pred in models.items():
    report = classification_report(y_test, y_pred, output_dict=True)
    rows.append({
        'Model':         name,
        'Accuracy':      f"{accuracy_score(y_test, y_pred):.1%}",
        'Macro F1':      f"{report['macro avg']['f1-score']:.3f}",
        'Underval F1':   f"{report['0']['f1-score']:.3f}",
        'Fair Val F1':   f"{report['1']['f1-score']:.3f}",
        'Overval F1':    f"{report['2']['f1-score']:.3f}",
        'Selected':      'YES' if name == 'XGBoost' else '',
    })

summary_df = pd.DataFrame(rows)
print('\n=== MODEL COMPARISON SUMMARY ===')
print(summary_df.to_string(index=False))
summary_df.to_csv('model_comparison_summary.csv', index=False)

# ── Visual table ──────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(12, 2.5))
ax.axis('off')
tbl = ax.table(
    cellText=summary_df.values,
    colLabels=summary_df.columns,
    cellLoc='center', loc='center'
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(10)
tbl.scale(1.0, 1.8)
# Blue header row
for j in range(len(summary_df.columns)):
    tbl[0, j].set_facecolor('#2E74B5')
    tbl[0, j].set_text_props(color='white', fontweight='bold')
# Highlight XGBoost row
for j in range(len(summary_df.columns)):
    tbl[1, j].set_facecolor('#E8F4FD')
plt.title('Model Comparison — Test Set Performance', fontsize=12, fontweight='bold', pad=10)
plt.savefig('model_comparison_table.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved: model_comparison_table.png')
print('Saved: model_comparison_summary.csv')

# %% [markdown]
# ---
# ## Section 2: Backtesting — Sliding Window Evaluation
# Train XGBoost on a historical period, predict on the following year.
# Tests whether the model generalises to unseen time periods and market conditions.
#
# **Windows:**
# - Window 1: Train 2020-2021 → Test 2022 (Rate rise / tech correction)
# - Window 2: Train 2021-2022 → Test 2023 (AI rally / recovery)
# - Window 3: Train 2022-2023 → Test 2024 (Bull market)

# %%
import yfinance as yf, time, warnings
warnings.filterwarnings('ignore')
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score

BACKTEST_TICKERS = ['AAPL', 'MSFT', 'TSLA', 'JPM', 'XOM']
BACKTEST_WINDOWS = [
    ('2020-01-01', '2021-12-31', '2022-01-01', '2022-12-31', '2022 (Rate Rise)'),
    ('2021-01-01', '2022-12-31', '2023-01-01', '2023-12-31', '2023 (AI Rally)'),
    ('2022-01-01', '2023-12-31', '2024-01-01', '2024-12-31', '2024 (Bull Market)'),
]
# Reuse SECTOR_MAP defined earlier in the notebook

def build_features_for_window(ticker, start, end):
    """
    Fetch price history for a time window and build the same features
    used during training. Returns a labelled DataFrame or None.
    """
    warmup = (pd.Timestamp(start) - pd.DateOffset(months=6)).strftime('%Y-%m-%d')
    try:
        hist = yf.Ticker(ticker).history(start=warmup, end=end)
        if hist.empty: return None
        info = yf.Ticker(ticker).info
        time.sleep(0.3)
    except:
        return None

    eps     = info.get('trailingEps') or info.get('forwardEps')
    bv      = info.get('bookValue')
    pe      = info.get('trailingPE')
    roe     = info.get('returnOnEquity')
    roa     = info.get('returnOnAssets')
    dy      = info.get('dividendYield') or 0.0
    p2b     = info.get('priceToBook')
    p2s     = info.get('priceToSalesTrailing12Months')
    opm     = info.get('operatingMargins')
    rg      = info.get('revenueGrowth')
    rs      = info.get('sector')
    de_raw  = info.get('debtToEquity')
    de      = (de_raw / 100) if de_raw else 0.0

    if any(v is None for v in [eps, bv, roe, roa, p2b, p2s, opm, rg, rs]):
        return None
    if pe is None:
        pe = (hist['Close'].iloc[-1] / eps) if eps and eps != 0 else None
    if pe is None: return None

    sector = SECTOR_MAP.get(rs)
    if not sector: return None

    gv = float(np.sqrt(22.5 * abs(eps * bv))) if eps and bv else 0

    def lbl(p):
        if gv == 0: return 1
        if p < gv * 0.85: return 0
        if p > gv * 1.15: return 2
        return 1

    sp500 = yf.Ticker('^GSPC').history(start=warmup, end=end)['Close']
    hist.index  = hist.index.tz_convert(None)
    sp500.index = sp500.index.tz_convert(None)
    sp500 = sp500.reindex(hist.index).ffill()

    df = hist.copy()
    df['Target'] = df['Close'].apply(lbl)
    df['PE_Ratio'] = pe; df['ROE'] = roe; df['ROA'] = roa
    df['EPS'] = eps; df['Dividend_Yield'] = dy; df['Debt_to_Equity'] = de
    df['Price_to_Book'] = p2b; df['Price_to_Sales'] = p2s
    df['Revenue_Growth'] = rg; df['Operating_Margin'] = opm
    df['Momentum']   = df['Close'].rolling(30).mean() / df['Close'].rolling(90).mean()
    df['Volatility'] = df['Close'].pct_change().rolling(30).std()
    df['sp500_close'] = sp500
    df[f'Sector_{sector}'] = 1

    all_cols = [
        'PE_Ratio','ROE','ROA','EPS','Dividend_Yield','Debt_to_Equity',
        'Price_to_Book','Price_to_Sales','Revenue_Growth','Operating_Margin',
        'Momentum','Volatility','sp500_close','Target',
        'Sector_Discretionary','Sector_Energy','Sector_Financials',
        'Sector_Healthcare','Sector_Industrials','Sector_Staples',
        'Sector_Technology','Sector_Utilities',
    ]
    for c in all_cols:
        if c not in df.columns: df[c] = 0
    df = df[all_cols].ffill().fillna(0).iloc[90:]
    df = df[df.index >= pd.Timestamp(start)]
    return df if not df.empty else None

print('Backtesting helpers ready.')

# %%
backtest_rows = []

for tr_s, tr_e, te_s, te_e, win_label in BACKTEST_WINDOWS:
    print(f'\nWindow: {win_label}')
    print(f'  Train: {tr_s} to {tr_e}   Test: {te_s} to {te_e}')

    # --- Collect training data ---
    train_frames = []
    for t in BACKTEST_TICKERS:
        df = build_features_for_window(t, tr_s, tr_e)
        if df is not None: train_frames.append(df)

    if not train_frames:
        print('  No training data — skipping'); continue

    tr = pd.concat(train_frames).sample(frac=1, random_state=42)
    X_tr = tr.drop(columns=['Target'])
    y_tr = tr['Target']

    # --- Retrain XGBoost on this window ---
    bt_model = XGBClassifier(
        n_estimators=100, max_depth=4, learning_rate=0.05,
        subsample=0.8, colsample_bytree=0.6,
        eval_metric='mlogloss', random_state=42, verbosity=0
    )
    bt_model.fit(X_tr, y_tr)

    # --- Evaluate on each ticker's test period ---
    for ticker in BACKTEST_TICKERS:
        te = build_features_for_window(ticker, te_s, te_e)
        if te is None or te.empty:
            print(f'    {ticker}: no test data'); continue

        X_te = te.drop(columns=['Target'])
        y_te = te['Target']

        for c in X_tr.columns:
            if c not in X_te.columns: X_te[c] = 0
        X_te = X_te[X_tr.columns]

        y_hat = bt_model.predict(X_te)
        acc   = accuracy_score(y_te, y_hat)
        f1    = f1_score(y_te, y_hat, average='macro', zero_division=0)
        print(f'    {ticker:5s} accuracy={acc:.1%}  macro_f1={f1:.3f}')
        backtest_rows.append({
            'Window': win_label, 'Ticker': ticker,
            'Accuracy': acc, 'Macro F1': f1
        })

backtest_df = pd.DataFrame(backtest_rows)
print('\n=== BACKTESTING COMPLETE ===')
print(backtest_df.to_string(index=False))
backtest_df.to_csv('backtest_summary.csv', index=False)

# %%
# ── Heatmap: accuracy per ticker per window ────────────────────────────────
pivot = backtest_df.pivot(index='Ticker', columns='Window', values='Accuracy')

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Heatmap
sns.heatmap(
    pivot, annot=True, fmt='.0%', cmap='RdYlGn',
    vmin=0.35, vmax=0.85, ax=axes[0], linewidths=0.5
)
axes[0].set_title('Backtesting Accuracy per Ticker per Window',
                  fontsize=11, fontweight='bold')
axes[0].set_xlabel('')

# Bar chart: average accuracy per window
avg_acc = backtest_df.groupby('Window')['Accuracy'].mean()
colors  = ['#2E74B5' if v >= 0.60 else '#C00000' for v in avg_acc.values]
bars = axes[1].bar(avg_acc.index, avg_acc.values, color=colors, alpha=0.85, edgecolor='white')
axes[1].axhline(0.60, color='green', linestyle='--', linewidth=1.2, label='60% target')
axes[1].axhline(1/3,  color='grey',  linestyle=':', linewidth=1,   label='Random baseline')
for bar in bars:
    h = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2, h + 0.01,
                 f'{h:.0%}', ha='center', fontsize=10, fontweight='bold')
axes[1].set_ylim(0, 1)
axes[1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axes[1].set_title('Average Accuracy per Window', fontsize=11, fontweight='bold')
axes[1].legend(fontsize=9)
axes[1].set_xlabel('')

plt.suptitle('Backtesting Results — XGBoost Sliding Window Evaluation',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('backtest_results.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved: backtest_results.png')
print('Saved: backtest_summary.csv')

# %% [markdown]
# ---
# ## Section 3: Simulated Investment Comparison
# Compare four strategies across 2022, 2023, 2024:
# - **Model (Undervalued)** — buy stocks the model labels as Undervalued at start of year
# - **Model (Overvalued)** — buy what the model says to avoid (proves model signal is real)
# - **S&P 500 (SPY)** — passive benchmark
# - **Random** — Monte Carlo average of 100 random picks from universe

# %%
import joblib

SIM_UNIVERSE = [
    'AAPL','MSFT','NVDA','INTC','CSCO',   # Technology
    'JPM','BAC','GS','V','MA',             # Financials
    'JNJ','PFE','UNH','MRK','ABBV',        # Healthcare
    'XOM','CVX','COP','SLB','EOG',          # Energy
]
model_cols = joblib.load('model_columns.pkl')

# ── Signal year: get model labels at start of 2020 ───────────────────────
# We use 2020 as the signal year — buy and hold through to 2024
# This reflects how value investing actually works: patient long-term holding
SIGNAL_YEAR  = 2020
HOLD_START   = '2020-01-02'
HOLD_END     = '2024-12-31'

# Annual periods for year-by-year comparison
ANNUAL_YEARS = [2020,2021,2022, 2023, 2024]

def get_model_signal(ticker, year):
    """Get model's predicted label for a ticker at the start of a year."""
    df = build_features_for_window(ticker, f'{year}-01-01', f'{year}-03-31')
    if df is None or df.empty: return None
    row = df.drop(columns=['Target']).iloc[[-1]]
    for c in model_cols:
        if c not in row.columns: row[c] = 0
    row = row[model_cols]
    try:
        return int(grid_xgb.best_estimator_.predict(row)[0])
    except:
        return None

def portfolio_return_series(tickers, start, end):
    """Equal weight portfolio normalised to 1.0 at start date."""
    if not tickers: return 0.0, pd.Series(dtype=float)
    frames = []
    for t in tickers:
        h = yf.Ticker(t).history(start=start, end=end)['Close']
        if h.empty: continue
        h.index = h.index.tz_convert(None)
        frames.append(h / h.iloc[0])
    if not frames: return 0.0, pd.Series(dtype=float)
    port = pd.concat(frames, axis=1).ffill().dropna().mean(axis=1)
    return round((port.iloc[-1] - 1) * 100, 2), port

def spy_return_series(start, end):
    """S&P 500 benchmark return for a given period."""
    spy = yf.Ticker('SPY').history(start=start, end=end)['Close']
    if spy.empty: return 0.0, pd.Series(dtype=float)
    spy.index = spy.index.tz_convert(None)
    norm = spy / spy.iloc[0]
    return round((norm.iloc[-1] - 1) * 100, 2), norm

def random_return(tickers, start, end, n=5, runs=100):
    """Monte Carlo — average of 100 random picks over a given period."""
    np.random.seed(42)
    rets = []
    for _ in range(runs):
        picks = list(np.random.choice(tickers, size=min(n, len(tickers)), replace=False))
        r, _  = portfolio_return_series(picks, start, end)
        rets.append(r)
    return round(np.mean(rets), 2)

def max_drawdown(series):
    if series.empty: return 0.0
    dd = (series - series.cummax()) / series.cummax()
    return round(dd.min() * 100, 2)

def sharpe(series, rf=0.04):
    if series.empty or len(series) < 2: return 0.0
    dr  = series.pct_change().dropna()
    exc = dr - rf / 252
    return round((exc.mean() / dr.std()) * np.sqrt(252), 2) if dr.std() != 0 else 0.0

print('Simulation helpers ready.')
# Out:
# Simulation helpers ready.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# PART A: Get model signals at start of 2020
# The model labels each stock as Undervalued (0), Fair Value (1), or Overvalued (2)
# We buy anything labelled 0 OR 1 — value investing avoids Overvalued stocks
# We also track Overvalued picks as a control to prove the signal has direction
# ─────────────────────────────────────────────────────────────────────────────
print('Getting model signals for', SIGNAL_YEAR, '...')
signals = {t: get_model_signal(t, SIGNAL_YEAR) for t in SIM_UNIVERSE}
signals = {t: l for t, l in signals.items() if l is not None}

# Undervalued or Fair Value — stocks the model says are reasonably priced
good_picks = [t for t, l in signals.items() if l in (0, 1)]
# Overvalued — stocks the model says to avoid
bad_picks  = [t for t, l in signals.items() if l == 2]

print(f'Good picks (Undervalued + Fair): {good_picks}')
print(f'Avoid picks (Overvalued):        {bad_picks}')

# ─────────────────────────────────────────────────────────────────────────────
# PART B: 5-YEAR LONG-TERM HOLD (2020-2024)
# Buy at start of 2020, hold through to end of 2024 — no rebalancing
# This is how value investing actually works
# ─────────────────────────────────────────────────────────────────────────────
print('\n--- 5-Year Long-Term Simulation (2020-2024) ---')
ret_good_5y, s_good_5y = portfolio_return_series(good_picks, HOLD_START, HOLD_END)
ret_bad_5y,  s_bad_5y  = portfolio_return_series(bad_picks,  HOLD_START, HOLD_END)
ret_spy_5y,  s_spy_5y  = spy_return_series(HOLD_START, HOLD_END)
ret_rand_5y             = random_return(SIM_UNIVERSE, HOLD_START, HOLD_END)

print(f'Model (Good: UV+Fair):   {ret_good_5y:+.1f}%')
print(f'Model (Avoid Overvalued):{ret_bad_5y:+.1f}%')
print(f'S&P 500 (SPY):           {ret_spy_5y:+.1f}%')
print(f'Random (avg 100 runs):   {ret_rand_5y:+.1f}%')

long_term = {
    'Model (Undervalued + Fair)': (ret_good_5y, s_good_5y),
    'Model (Overvalued — avoid)': (ret_bad_5y,  s_bad_5y),
    'S&P 500':                    (ret_spy_5y,  s_spy_5y),
}

# ─────────────────────────────────────────────────────────────────────────────
# PART C: YEAR-BY-YEAR COMPARISON (2022, 2023, 2024)
# Fresh signals each year — shows short-term performance per year
# ─────────────────────────────────────────────────────────────────────────────
print('\n--- Annual Simulation (fresh signals each year) ---')
annual_rows = []
chart_good  = {}
chart_spy   = {}

for year in ANNUAL_YEARS:
    print(f'\nYear {year}:')
    yr_signals = {t: get_model_signal(t, year) for t in SIM_UNIVERSE}
    yr_signals = {t: l for t, l in yr_signals.items() if l is not None}

    yr_good = [t for t, l in yr_signals.items() if l in (0, 1)]
    yr_bad  = [t for t, l in yr_signals.items() if l == 2]
    start   = f'{year}-01-02'
    end     = f'{year}-12-31'

    ret_good, s_good = portfolio_return_series(yr_good, start, end)
    ret_bad,  _      = portfolio_return_series(yr_bad,  start, end)
    ret_spy,  s_spy  = spy_return_series(start, end)
    ret_rand          = random_return(SIM_UNIVERSE, start, end)

    chart_good[year] = s_good
    chart_spy[year]  = s_spy

    print(f'  Good picks: {yr_good}')
    print(f'  UV+Fair: {ret_good:+.1f}%   Overvalued: {ret_bad:+.1f}%   SPY: {ret_spy:+.1f}%   Random: {ret_rand:+.1f}%')

    annual_rows.append({
        'Year':              year,
        'Model (UV+Fair) %': ret_good,
        'Model (OV) %':      ret_bad,
        'S&P 500 %':         ret_spy,
        'Random %':          ret_rand,
        'Max Drawdown %':    max_drawdown(s_good),
        'Sharpe Ratio':      sharpe(s_good),
        'Beat SPY':          'YES' if ret_good > ret_spy else 'NO',
    })

annual_df = pd.DataFrame(annual_rows)
print('\n=== ANNUAL SUMMARY ===')
print(annual_df.to_string(index=False))
annual_df.to_csv('simulation_annual.csv', index=False)
# Out:
# Getting model signals for 2020 ...
# Good picks (Undervalued + Fair): ['AAPL', 'MSFT', 'NVDA', 'CSCO', 'JPM', 'BAC', 'GS', 'V', 'MA', 'JNJ', 'PFE', 'UNH', 'MRK', 'XOM', 'CVX', 'COP', 'SLB', 'EOG']
# Avoid picks (Overvalued):        ['INTC', 'ABBV']
#
# --- 5-Year Long-Term Simulation (2020-2024) ---
# Model (Good: UV+Fair):   +197.2%
# Model (Avoid Overvalued):+40.4%
# S&P 500 (SPY):           +95.3%
# Random (avg 100 runs):   +177.9%
#
# --- Annual Simulation (fresh signals each year) ---
#
# Year 2020:
#   Good picks: ['AAPL', 'MSFT', 'NVDA', 'CSCO', 'JPM', 'BAC', 'GS', 'V', 'MA', 'JNJ', 'PFE', 'UNH', 'MRK', 'XOM', 'CVX', 'COP', 'SLB', 'EOG']
#   UV+Fair: +5.6%   Overvalued: +3.1%   SPY: +16.6%   Random: +3.8%
#
# Year 2021:
#   Good picks: ['AAPL', 'MSFT', 'NVDA', 'BAC', 'GS', 'V', 'MA', 'PFE', 'MRK', 'XOM', 'CVX', 'COP', 'SLB', 'EOG']
#   UV+Fair: +50.7%   Overvalued: +29.7%   SPY: +30.8%   Random: +43.8%
#
# Year 2022:
#   Good picks: ['AAPL', 'MSFT', 'NVDA', 'INTC', 'BAC', 'GS', 'V', 'MA', 'PFE', 'UNH', 'MRK', 'XOM', 'CVX', 'COP', 'SLB', 'EOG']
#   UV+Fair: +10.8%   Overvalued: -1.8%   SPY: -18.6%   Random: +8.7%
#
# Year 2023:
#   Good picks: ['AAPL', 'MSFT', 'NVDA', 'BAC', 'GS', 'V', 'MA', 'PFE', 'MRK', 'XOM', 'CVX', 'COP', 'SLB', 'EOG']
#   UV+Fair: +27.5%   Overvalued: +20.6%   SPY: +26.7%   Random: +24.3%
#
# Year 2024:
#   Good picks: ['AAPL', 'MSFT', 'NVDA', 'BAC', 'GS', 'V', 'MA', 'PFE', 'MRK']
#   UV+Fair: +39.2%   Overvalued: -2.2%   SPY: +26.1%   Random: +16.9%
#
# === ANNUAL SUMMARY ===
#  Year  Model (UV+Fair) %  Model (OV) %  S&P 500 %  Random %  Max Drawdown %  Sharpe Ratio Beat SPY
#  2020               5.56          3.09      16.64      3.78          -38.97          0.24       NO
#  2021              50.73         29.68      30.84     43.78           -7.87          2.08      YES
#  2022              10.83         -1.75     -18.65      8.65          -17.64          0.38      YES
#  2023              27.51         20.60      26.71     24.32           -9.63          1.42      YES
#  2024              39.24         -2.19      26.05     16.92          -10.98          1.96      YES

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ── Chart 1: 5-Year long-term portfolio value ─────────────────────────────
colors_lt = {
    'Model (Undervalued + Fair)': '#2E74B5',
    'Model (Overvalued — avoid)': '#C00000',
    'S&P 500':                    '#70AD47',
}
styles_lt = {
    'Model (Undervalued + Fair)': '-',
    'Model (Overvalued — avoid)': '--',
    'S&P 500':                    ':',
}
for label, (ret, series) in long_term.items():
    if series.empty: continue
    axes[0].plot(
        series.index, series * 10000,
        label=f'{label} ({ret:+.0f}%)',
        color=colors_lt[label], linewidth=2.2,
        linestyle=styles_lt[label]
    )
axes[0].axhline(10000, color='grey', linewidth=0.8, linestyle=':', alpha=0.6)
axes[0].set_title('5-Year Long-Term Hold (2020-2024)\n£10,000 Starting Capital',
                  fontsize=11, fontweight='bold')
axes[0].set_ylabel('Portfolio Value (£)')
axes[0].yaxis.set_major_formatter(mtick.StrMethodFormatter('£{x:,.0f}'))
axes[0].legend(fontsize=9)
axes[0].set_xlabel('Date')

# ── Chart 2: Annual returns grouped bar chart ─────────────────────────────
strategies = ['Model (UV+Fair) %', 'Model (OV) %', 'S&P 500 %', 'Random %']
bar_labels = ['Model\n(UV + Fair)', 'Model\n(Overvalued)', 'S&P 500', 'Random']
bar_colors = ['#2E74B5', '#C00000', '#70AD47', '#999999']
x     = np.arange(len(ANNUAL_YEARS))
width = 0.2

for i, (col, lbl, color) in enumerate(zip(strategies, bar_labels, bar_colors)):
    vals = annual_df[col].values
    bars = axes[1].bar(x + i * width, vals, width, label=lbl, color=color, alpha=0.85)
    for bar in bars:
        h = bar.get_height()
        axes[1].text(
            bar.get_x() + bar.get_width() / 2,
            h + (0.8 if h >= 0 else -3.5),
            f'{h:+.1f}%', ha='center', fontsize=7.5
        )

axes[1].axhline(0, color='black', linewidth=0.8)
axes[1].set_xticks(x + width * 1.5)
axes[1].set_xticklabels([str(y) for y in ANNUAL_YEARS])
axes[1].yaxis.set_major_formatter(mtick.PercentFormatter())
axes[1].set_title('Annual Return by Strategy\n(Fresh signals each year)',
                  fontsize=11, fontweight='bold')
axes[1].set_ylabel('Total Return (%)')
axes[1].legend(fontsize=8)

plt.suptitle('Simulated Investment Comparison — Model vs S&P 500 vs Random',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('simulation_results.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved: simulation_results.png')
# Out:
# Saved: simulation_results.png

# %%
# ── Long-term summary row ─────────────────────────────────────────────────
lt_row = pd.DataFrame([{
    'Period':          '2020-2024 (5yr)',
    'Model (UV+Fair)': f'{ret_good_5y:+.1f}%',
    'Model (OV)':      f'{ret_bad_5y:+.1f}%',
    'S&P 500':         f'{ret_spy_5y:+.1f}%',
    'Random':          f'{ret_rand_5y:+.1f}%',
    'Max Drawdown':    f'{max_drawdown(s_good_5y):.1f}%',
    'Sharpe':          f'{sharpe(s_good_5y):.2f}',
    'Beat SPY':        'YES' if ret_good_5y > ret_spy_5y else 'NO',
}])

# Annual rows formatted
annual_disp = annual_df.copy()
annual_disp.columns = [
    'Period','Model (UV+Fair)','Model (OV)','S&P 500','Random',
    'Max Drawdown','Sharpe','Beat SPY'
]
for col in ['Model (UV+Fair)','Model (OV)','S&P 500','Random']:
    annual_disp[col] = annual_disp[col].apply(lambda v: f'{v:+.1f}%')
annual_disp['Max Drawdown'] = annual_disp['Max Drawdown'].apply(lambda v: f'{v:.1f}%')
annual_disp['Sharpe']       = annual_disp['Sharpe'].apply(lambda v: f'{v:.2f}')
annual_disp['Period']       = annual_disp['Period'].astype(str)

full_table = pd.concat([lt_row, annual_disp], ignore_index=True)

fig, ax = plt.subplots(figsize=(14, 2.8))
ax.axis('off')
tbl = ax.table(
    cellText=full_table.values, colLabels=full_table.columns,
    cellLoc='center', loc='center'
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(9.5)
tbl.scale(1.0, 1.85)
# Blue header
for j in range(len(full_table.columns)):
    tbl[0, j].set_facecolor('#2E74B5')
    tbl[0, j].set_text_props(color='white', fontweight='bold')
# Gold highlight for 5-year row
for j in range(len(full_table.columns)):
    tbl[1, j].set_facecolor('#FFF2CC')
# Green/red for Beat SPY column
beat_col = list(full_table.columns).index('Beat SPY')
for i in range(1, len(full_table) + 1):
    val = full_table.iloc[i-1]['Beat SPY']
    tbl[i, beat_col].set_facecolor('#E2EFDA' if val == 'YES' else '#FFDCDC')
plt.title('Full Simulation Results — Long-Term and Annual Comparison',
          fontsize=12, fontweight='bold', pad=10)
plt.savefig('simulation_metrics_table.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved: simulation_metrics_table.png')
print('Saved: simulation_annual.csv')
# Out:
# Saved: simulation_metrics_table.png
# Saved: simulation_annual.csv

# %%
import yfinance as yf

# Fetch AAPL with a 2008 date range
ticker = yf.Ticker("AAPL")
hist   = ticker.history(start="2008-01-01", end="2008-12-31")
info   = ticker.info

print("=== Price history date range ===")
print(f"First date in hist: {hist.index[0].date()}")
print(f"Last date in hist:  {hist.index[-1].date()}")
print(f"First Close price:  ${hist['Close'].iloc[0]:.2f}  (should be ~$28)")
print(f"Last Close price:   ${hist['Close'].iloc[-1]:.2f}  (should be ~$11)")

print("\n=== Fundamentals from info ===")
print(f"trailingEps: {info.get('trailingEps')}  <-- is this ~$0.50 (2008) or ~$6.50 (today)?")
print(f"bookValue:   {info.get('bookValue')}  <-- is this ~$5 (2008) or ~$4 (today, negative equity)?")
print(f"trailingPE:  {info.get('trailingPE')}  <-- is this ~20 (2008) or ~33 (today)?")

print("\n=== Graham value computed ===")
eps = info.get('trailingEps')
bv  = info.get('bookValue')
gv  = (22.5 * abs(eps * bv)) ** 0.5 if eps and bv else 0
print(f"Graham value: ${gv:.2f}")
print(f"2008 price was ~$28 — label would be: {'Undervalued' if 28 < gv*0.85 else 'Overvalued' if 28 > gv*1.15 else 'Fair Value'}")
print(f"\nIf EPS were the real 2008 value (~$0.50):")
gv_real = (22.5 * abs(0.50 * 5.10)) ** 0.5
print(f"Real 2008 Graham value: ${gv_real:.2f}")
print(f"Real 2008 label would be: {'Undervalued' if 28 < gv_real*0.85 else 'Overvalued' if 28 > gv_real*1.15 else 'Fair Value'}")
# Out:
# === Price history date range ===
# First date in hist: 2008-01-02
# Last date in hist:  2008-12-30
# First Close price:  $5.84  (should be ~$28)
# Last Close price:   $2.59  (should be ~$11)
#
# === Fundamentals from info ===
# trailingEps: 7.91  <-- is this ~$0.50 (2008) or ~$6.50 (today)?
# bookValue:   5.998  <-- is this ~$5 (2008) or ~$4 (today, negative equity)?
# trailingPE:  31.351456  <-- is this ~20 (2008) or ~33 (today)?
#
# === Graham value computed ===
# Graham value: $32.67
# 2008 price was ~$28 — label would be: Fair Value
#
# If EPS were the real 2008 value (~$0.50):
# Real 2008 Graham value: $7.57
# Real 2008 label would be: Overvalued
